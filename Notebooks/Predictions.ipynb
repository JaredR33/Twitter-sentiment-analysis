# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clean_data.csv', index_col=0)
df[df['original_language'] == 'eusk']
# Out:
#              author_id                created_at                   id  \
# 29           146406912  2022-11-30T15:55:35.000Z  1597982684487340040
# 36  702077405045899264  2022-11-30T09:33:32.000Z  1597886536896450562
# 38  702077405045899264  2022-11-30T09:09:45.000Z  1597880551578419201
# 40  702077405045899264  2022-11-30T08:53:19.000Z  1597876414908432385
# 42  702077405045899264  2022-11-30T08:43:35.000Z  1597873965812285440
# 46  702077405045899264  2022-11-30T08:13:41.000Z  1597866442841628672
# 58  702077405045899264  2022-11-22T08:05:10.000Z  1594965197613322241
#
#                                                  text  impression_count  \
# 29  guillerdorron rt bbk_eus 🤔 zer dira bbk eta th...                 0
# 36  🗣 tomás iriondo clustergaia -ko ceo #eteari la...                 0
# 38  🤔 zer dira bbk eta thebridge_tech -en #bbkboot...                 0
# 40  🗣 iker arcerekin thebridge_tech -eko ceo-a jar...                 0
# 42  🗣 nora sarasolak bbk-ko gizarte ekintzako zuze...                 0
# 46  🔛 aurkezpen eguna thebridge_tech eta #bbk -k i...                 0
# 58  ikasi gaur etorkizuneko lanbideak izena eman #...                 0
#
#     like_count  quote_count  reply_count  retweet_count  year  month  \
# 29           0            0            0              0  2022     11
# 36           3            0            0              1  2022     11
# 38           4            0            0              2  2022     11
# 40           3            0            0              1  2022     11
# 42           3            0            0              1  2022     11
# 46           2            0            0              1  2022     11
# 58           2            0            0              1  2022     11
#
#    original_language
# 29              eusk
# 36              eusk
# 38              eusk
# 40              eusk
# 42              eusk
# 46              eusk
# 58              eusk

# %% [markdown]
# DATA PROCESSING

# %%
#TRANSLATION INTO SPA

# %%
#eliminar signos

import re

signos = re.compile("(\.)|(\;)|(\:)|(\!)|(\?)|(\¿)|(\@)|(\,)|(\")|(\()|(\))|(\[)|(\])|(\d+)|(\¡)")

def signs_tweets(tweet):
    return signos.sub('', tweet.lower())

df['text'] = df['text'].apply(signs_tweets)
df['text'].head()
# Out:
# 0    empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...
# 1    bootcamps tecnológicos edem thebridge_tech emp...
# 2    edemempresarios acoge enero open day participa...
# 3    si buscando profesión cambie vida acércate ope...
# 4    thebridge_tech deseo ti💫 qué venga cargado éxi...
# Name: text, dtype: object

# %%
#eliminar links

def remove_links(df):
    return " ".join(['{link}' if ('http') in word else word for word in df.split()])

df['text'] = df['text'].apply(remove_links)

# %%
#eliminar stopwords

from nltk.corpus import stopwords

spanish_stopwords = stopwords.words('spanish')

def remove_stopwords(df):
    return " ".join([word for word in df.split() if word not in spanish_stopwords])

# %%
df['text'] = df['text'].apply(remove_stopwords)

# %%
df.text.head()
# Out:
# 0    empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...
# 1    bootcamps tecnológicos edem thebridge_tech emp...
# 2    edemempresarios acoge enero open day participa...
# 3    si buscando profesión cambie vida acércate ope...
# 4    thebridge_tech deseo ti💫 venga cargado éxitos ...
# Name: text, dtype: object

# %%
# Clean emojis 
import emoji 


df['text'] = df['text'].apply(lambda x: emoji.demojize(x))

# %%
df[df['original_language'] != 'es']['text']
# Out:
# 13     libertariadora javieramaestre kilrau gabohbeau...
# 22     :light_bulb: interesante intervención ramón lo...
# 24     :BACK_arrow: atzo oso jardunaldi interesgarria...
# 29     guillerdorron rt bbk_eus :thinking_face: zer d...
# 31     guillerdorron rt bbk_eus #bbkbootcamps | :spea...
# 32     open day #bilbao conocer #bootcam :spiral_cale...
# 33     #bbkbootcamps | :speaking_head: guillermo dorr...
# 35     #bbkbootcamps | :speaking_head: ramón lozano d...
# 36     :speaking_head: tomás iriondo clustergaia -ko ...
# 38     :thinking_face: zer dira bbk eta thebridge_tec...
# 40     :speaking_head: iker arcerekin thebridge_tech ...
# 42     :speaking_head: nora sarasolak bbk-ko gizarte ...
# 44     :hot_beverage::croissant: jardunaldia enpresen...
# 46     :ON!_arrow: aurkezpen eguna thebridge_tech eta...
# 56     ven conocer bbk bootcamps powered by thebridge...
# 58     ikasi gaur etorkizuneko lanbideak izena eman #...
# 65            paumugarra tonidorta thebridge_tech {link}
# 68     rperezmarco bitcointuesday_ thebridge_tech :ba...
# 71     decentralized_b bitcointuesday_ thebridge_tech...
# 73                    thebridge_tech vacolba interesante
# 74     thebridge_tech product marketing specialist on...
# 82     thebridge_tech vacolba andresmacariog interesante
# 88     inicia masterclass #datascience #ia gobernarlo...
# 89     masterclass data science bootcamps bbk powered...
# 91     interesantísima jornada #proptechthursdays the...
# 93     hoy bbk_kuna :brain::robot: masterclass inteli...
# 97     nodosenlared snowded thebridge_tech check my b...
# 99     jorgegrev was one of the reasons i got into co...
# 103           nodosenlared snowded thebridge_tech {link}
# 108           nodosenlared snowded thebridge_tech {link}
# 121    recuenco ae_bm thebridge_tech ddamasd :victory...
# 126    godivaciones recuenco thebridge_tech ddamasd m...
# 130      plena meet-up cps thebridge_tech ddamasd {link}
# Name: text, dtype: object

# %%
'''#Because of 'translate' module memory problems we will use microsoft translation package'''

from translate import Translator

# Initialize translator object
translator = Translator(to_lang='es')

# Translate the 'text' column if 'original_language' is not 'es'
df['text_es'] = df.apply(lambda x: translator.translate(x['text']) if x['original_language'] != 'es' else x['text'], axis=1)

# Print the translated dataframe
print(df)
# Out:
#                author_id                created_at                   id  \
# 0    1151510939105144834  2022-12-29T16:39:19.000Z  1608502937332113408
# 1              570795448  2022-12-29T12:52:11.000Z  1608445776732246017
# 2             1128860148  2022-12-29T09:16:11.000Z  1608391421014196224
# 3              570795448  2022-12-27T09:00:57.000Z  1607662809575292929
# 4    1162694149956603904  2022-12-23T12:54:06.000Z  1606271930763354112
# ..                   ...                       ...                  ...
# 144            271028835  2023-01-07T19:55:52.000Z  1611813891322908672
# 145  1530194743786881024  2023-01-06T12:28:27.000Z  1611338908196913153
# 146             10279282  2023-01-04T15:02:11.000Z  1610652818234347521
# 147           2402179123  2023-01-04T11:57:41.000Z  1610606391445815297
# 148   874916978665938945  2023-01-02T15:15:00.000Z  1609931268921114627
#
#                                                   text  impression_count  \
# 0    empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...               113
# 1    bootcamps tecnológicos edem thebridge_tech emp...               124
# 2    edemempresarios acoge enero open day participa...                49
# 3    si buscando profesión cambie vida acércate ope...               218
# 4    thebridge_tech deseo ti:dizzy: venga cargado é...               120
# ..                                                 ...               ...
# 144  :rocket: edemempresarios thebridge_tech alían ...               166
# 145  gracias amigos thebridge_tech acogernos vez :f...                51
# 146  interesa diseño #producto digital ven #masterc...                82
# 147  empezamos año #masterclass #uxui introducción ...               116
# 148  :handshake: edemempresarios alía thebridge_tec...               593
#
#      like_count  quote_count  reply_count  retweet_count  year  month  \
# 0             4            0            0              1  2022     12
# 1             2            0            0              0  2022     12
# 2             2            0            0              0  2022     12
# 3             5            0            0              0  2022     12
# 4             1            0            0              1  2022     12
# ..          ...          ...          ...            ...   ...    ...
# 144           7            0            0              2  2023      1
# 145           2            0            0              0  2023      1
# 146           3            0            0              2  2023      1
# 147           3            0            0              2  2023      1
# 148           5            0            0              1  2023      1
#
#     original_language                                            text_es
# 0                  es  empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...
# 1                  es  bootcamps tecnológicos edem thebridge_tech emp...
# 2                  es  edemempresarios acoge enero open day participa...
# 3                  es  si buscando profesión cambie vida acércate ope...
# 4                  es  thebridge_tech deseo ti:dizzy: venga cargado é...
# ..                ...                                                ...
# 144                es  :rocket: edemempresarios thebridge_tech alían ...
# 145                es  gracias amigos thebridge_tech acogernos vez :f...
# 146                es  interesa diseño #producto digital ven #masterc...
# 147                es  empezamos año #masterclass #uxui introducción ...
# 148                es  :handshake: edemempresarios alía thebridge_tec...
#
# [149 rows x 13 columns]

# %%
df['text_es'][29]
# Out:
# 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  22 HOURS 49 MINUTES 56 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE'

# %%
from mtranslate import translate

# Define la función de traducción
def translate_text(row):
    # Traduce el texto a español
    return translate(row['text'], 'es')

# Aplica la función de traducción a la columna 'text'
df['text_es'] = df.apply(translate_text, axis=1)
# Out:
#                author_id                created_at                   id  \
# 0    1151510939105144834  2022-12-29T16:39:19.000Z  1608502937332113408
# 1              570795448  2022-12-29T12:52:11.000Z  1608445776732246017
# 2             1128860148  2022-12-29T09:16:11.000Z  1608391421014196224
# 3              570795448  2022-12-27T09:00:57.000Z  1607662809575292929
# 4    1162694149956603904  2022-12-23T12:54:06.000Z  1606271930763354112
# ..                   ...                       ...                  ...
# 144            271028835  2023-01-07T19:55:52.000Z  1611813891322908672
# 145  1530194743786881024  2023-01-06T12:28:27.000Z  1611338908196913153
# 146             10279282  2023-01-04T15:02:11.000Z  1610652818234347521
# 147           2402179123  2023-01-04T11:57:41.000Z  1610606391445815297
# 148   874916978665938945  2023-01-02T15:15:00.000Z  1609931268921114627
#
#                                                   text  impression_count  \
# 0    empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯
# 130    plena meet-up cps thebridge_tech ddamasd {link}              6600
#
#      like_count  quote_count  reply_count  retweet_count  year  month  \
# 13            2            0            0              0  2022     12
# 22            4            0            0              1  2022     12
# 24            0            0            0              0  2022     12
# 29            0            0            0              0  2022     11
# 31            0            0            0              0  2022     11
# 32            9            0            0              5  2022     11
# 33            5            3            0              3  2022     11
# 35            4            1            0              2  2022     11
# 36            3            0            0              1  2022     11
# 38            4            0            0              2  2022     11
# 40            3            0            0              1  2022     11
# 42            3            0            0              1  2022     11
# 44            2            0            0              0  2022     11
# 46            2            0            0              1  2022     11
# 56            3            0            0              4  2022     11
# 58            2            0            0              1  2022     11
# 65            2            0            0              0  2023      3
# 68            0            0            0              0  2023      3
# 71            2            0            2              0  2023      3
# 73            0            0            0              0  2023      3
# 74            0            0            0              0  2023      2
# 82            1            0            0              0  2023      2
# 88            1            0            0              0  2023      2
# 89            0            0            0              0  2023      2
# 91            4            0            0              2  2023      2
# 93            6            0            0              4  2023      2
# 97            0            0            0              0  2023      1
# 99            1            0            1              1  2023      1
# 103           0            0            0              0  2023      1
# 108           0            0            0              0  2023      1
# 121           1            0            0              0  2023      1
# 126           1            0            1              0  2023      1
# 130          35            1            2              5  2023      1
#
#     original_language                                            text_es
# 13                 en  libertariadora javieramaestre kilrau gabohbeau...
# 22                 it  :light_bulb: interesante intervención ramón lo...
# 24                 nl  :BACK_arrow: Tuvimos un día muy interesante ay...
# 29               eusk  guillerdorron rt bbk_eus :thinking_face: what ...
# 31                 en  guillerdorron rt bbk_eus #bbkbootcamps | :habl...
# 32                 en  jornada de puertas abiertas #bilbao conocer #b...
# 33                 en  #bbkbootcamps | :hablando_cabeza: guillermo do...
# 35                 en  #bbkbootcamps | :hablando_cabeza: ramón lozano...
# 36               eusk  :hablando_cabeza: tomás iriondo clustergaia ce...
# 38               eusk  :thinking_face: qué son los #bbkbootcamps de b...
# 40               eusk  :hablando_cabeza: con iker arce seguimos al ce...
# 42               eusk  :hablando_cabeza: nora sarasolak, directora de...
# 44                 nl  :hot_beverage::croissant: el día comenzó con u...
# 46               eusk  :ON!_arrow: jornada de presentación thebridge_...
# 56                 en  ven a conocer bbk bootcamps powered by thebrid...
# 58               eusk  aprenda carreras futuras hoy mismo regístrese ...
# 65                 en       paumugarra tonidorta thebridge_tech {enlace}
# 68                 en  rperezmarco bitcointuesday_ thebridge_tech :ba...
# 71                 en  decentralized_b bitcointuesday_ thebridge_tech...
# 73                 en                 thebridge_tech vacolba interesante
# 74                 en  thebridge_tech especialista en marketing de pr...
# 82                 en  thebridge_tech vacolba andresmacariog interesante
# 88                 en  empezar masterclass #datascience #ia gobernarl...
# 89                 en  masterclass data science bootcamps bbk impulsa...
# 91                 en  día interesante #proptechthursdays thefringela...
# 93                 en  hoy bbk_kuna :brain::robot: masterclass inteli...
# 97                 en  nodosenlared snowded thebridge_tech revisa mis...
# 99                 en  jorgegrev fue una de las razones por las que e...
# 103                en       nodosenlared snowded thebridge_tech {enlace}
# 108                en       nodosenlared snowded thebridge_tech {enlace}
# 121                en        ae_bm thebridge_tech ddamasd :victory_hand:
# 126                en  godivaciones recuenco thebridge_tech ddamasd m...
# 130                nl  Reunión completa CPS Thebridge_Tech DDAMASD {L...

# %%
#Con todo en el mismo idioma, podemos aplicar un stemmer

# %%
from nltk.stem.snowball import SnowballStemmer

def spanish_stemmer(x):
    stemmer = SnowballStemmer('spanish')
    return " ".join([stemmer.stem(word) for word in x.split()])

df['text_es'] = df['text_es'].apply(spanish_stemmer)
df['text_es'].head()
# Out:
# 0    empiez año formandot profesion 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯𝗼𝗿𝗮𝗹...
# 1    bootcamps tecnolog edem thebridge_tech emple d...
# 2    edemempresari acog ener open day particip resp...
# 3    si busc profesion cambi vid acercat open day p...
# 4    thebridge_tech dese ti:dizzy: veng carg exit f...
# Name: text_es, dtype: object

# %% [markdown]
# # PREDICCIONES

# %%
import pickle
with open('../models/sentiment_model', "rb") as archivo_entrada:
    model_pretrained = pickle.load(archivo_entrada)

# %%
model_pretrained
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(max_df=0.5, max_features=1000, min_df=5,
#                                  ngram_range=(1, 2))),
#                 ('cls', LogisticRegression(C=0.5))])

# %%
#gptJRO

# Cargar el modelo preentrenado
with open('model_pretrained.pkl', 'rb') as f:
    model = pickle.load(f)

# Crear una función para predecir la polaridad
def predict_sentiment(text):
    return model.predict([text])[0]

# Aplicar la función predict_sentiment() a la columna 'text_es' y agregar los resultados como una nueva columna 'polarity'
df['polarity'] = df['text_es'].apply(predict_sentiment)

# Imprimir el DataFrame resultante
print(df)

# %%
predictions = model_pretrained.predict(df['text_es'])
df['polarity'] = pd.DataFrame(predictions)
# Out:
#              author_id                created_at                   id  \
# 0  1151510939105144834  2022-12-29T16:39:19.000Z  1608502937332113408
# 1            570795448  2022-12-29T12:52:11.000Z  1608445776732246017
# 2           1128860148  2022-12-29T09:16:11.000Z  1608391421014196224
# 3            570795448  2022-12-27T09:00:57.000Z  1607662809575292929
# 4  1162694149956603904  2022-12-23T12:54:06.000Z  1606271930763354112
#
#                                                 text  impression_count  \
# 0  empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...               113
# 1  bootcamps tecnológicos edem thebridge_tech emp...               124
# 2  edemempresarios acoge enero open day participa...                49
# 3  si buscando profesión cambie vida acércate ope...               218
# 4  thebridge_tech deseo ti:dizzy: venga cargado é...               120
#
#    like_count  quote_count  reply_count  retweet_count  year  month  \
# 0           4            0            0              1  2022     12
# 1           2            0            0              0  2022     12
# 2           2            0            0              0  2022     12
# 3           5            0            0              0  2022     12
# 4           1            0            0              1  2022     12
#
#   original_language                                            text_es  \
# 0                es  empiez año formandot profesion 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯𝗼𝗿𝗮𝗹...
# 1                es  bootcamps tecnolog edem thebridge_tech emple d...
# 2                es  edemempresari acog ener open day particip resp...
# 3                es  si busc profesion cambi vid acercat open day p...
# 4                es  thebridge_tech dese ti:dizzy: veng carg exit f...
#
#    polarity
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df.head()
# Out:
#              author_id                created_at                   id  \
# 0  1151510939105144834  2022-12-29T16:39:19.000Z  1608502937332113408
# 1            570795448  2022-12-29T12:52:11.000Z  1608445776732246017
# 2           1128860148  2022-12-29T09:16:11.000Z  1608391421014196224
# 3            570795448  2022-12-27T09:00:57.000Z  1607662809575292929
# 4  1162694149956603904  2022-12-23T12:54:06.000Z  1606271930763354112
#
#                                                 text  impression_count  \
# 0  empieza año formándote profesiones 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯...               113
# 1  bootcamps tecnológicos edem thebridge_tech emp...               124
# 2  edemempresarios acoge enero open day participa...                49
# 3  si buscando profesión cambie vida acércate ope...               218
# 4  thebridge_tech deseo ti:dizzy: venga cargado é...               120
#
#    like_count  quote_count  reply_count  retweet_count  year  month  \
# 0           4            0            0              1  2022     12
# 1           2            0            0              0  2022     12
# 2           2            0            0              0  2022     12
# 3           5            0            0              0  2022     12
# 4           1            0            0              1  2022     12
#
#   original_language                                            text_es  \
# 0                es  empiez año formandot profesion 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯𝗼𝗿𝗮𝗹...
# 1                es  bootcamps tecnolog edem thebridge_tech emple d...
# 2                es  edemempresari acog ener open day particip resp...
# 3                es  si busc profesion cambi vid acercat open day p...
# 4                es  thebridge_tech dese ti:dizzy: veng carg exit f...
#
#    polarity
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# 4B - VARIABLES MAS IMPORTANTES DEL MODELO

# %%
import numpy as np

# Get the CountVectorizer step from the pipeline
vect_step = model_pretrained['vect']

# Get the LogisticRegression step from the pipeline
lr_step = model_pretrained['cls']

# Get the vocabulary from the CountVectorizer step
vocab = vect_step.get_feature_names()

# Get the coefficients from the LogisticRegression model
coefs = lr_step.coef_[0]

# Create a list of tuples with the feature names and coefficients
feat_coef = list(zip(vocab, coefs))

# Sort the list by absolute value of coefficient in descending order
feat_coef_sorted = sorted(feat_coef, key=lambda x: np.abs(x[1]), reverse=True)

# Print the top 10 most important features
for i in range(10):
    print(feat_coef_sorted[i])
# Out:
# ('encant', -1.8605111981502893)
# ('enhorabuen', -1.8449366081495842)
# ('graci', -1.805329609096349)
# ('buen', -1.6751185631684895)
# ('feliz', -1.4730851687952473)
# ('bes', -1.459032652806634)
# ('cuent', 1.427233666085361)
# ('deficit', 1.4022058325629765)
# ('blanc', 1.368604445686843)
# ('muert', 1.3502570413482133)
# c:\Users\rivas\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
model_pretrained
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(max_df=0.5, max_features=1000, min_df=5,
#                                  ngram_range=(1, 2))),
#                 ('cls', LogisticRegression(C=0.5))])

# %% [markdown]
# 4C - MEJORAR EL MODELO:
#
# - better data cleaning
# - aumentar muestra
# - hiperparametrizar diferente
# - mas modelos (aunque una Logisticregression suele ser una buena idea para los analisis de sentimiento hay otras opciones que pueden ser consideradas como un LinearSVC (mejor con outliers pero no tan interpretable) o un Naive Bayes)
